# %% [markdown]
# # simple example LLM + Prompt Template

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

load_dotenv()

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

assert GEMINI_API_KEY, "GEMINI_API_KEY is missing. Check your .env file."
assert OPENAI_API_KEY, "OPENAI_API_KEY is missing. Check your .env file."

print("Key loaded:", GEMINI_API_KEY[:6] + "..." )
print("OpenAI Key loaded:", OPENAI_API_KEY[:6] + "...")


# Initialize LLMs
gemini_llm = ChatGoogleGenerativeAI(
    temperature=0,
    model="gemini-2.5-flash",
    google_api_key=GEMINI_API_KEY
)
openai_llm = ChatOpenAI(
    temperature=0,
    model="gpt-3.5-turbo",
    openai_api_key=OPENAI_API_KEY
)

# Prompt template
prompt = PromptTemplate(
    input_variables=["product"],
    template="Give me a creative name for a company that makes {product}?",
)

# Example: Use Gemini
chain = prompt | gemini_llm
response = chain.invoke({"product": "smart home devices"})
print("Gemini response:", response)

# Example: Use OpenAI
chain = prompt | openai_llm
response = chain.invoke({"product": "smart home devices"})
print("OpenAI response:", response)
# Out:
# Key loaded: AIzaSy...
# OpenAI Key loaded: sk-pro...
# Gemini response: content='Here are some creative names for a smart home device company, categorized by style:\n\n## Modern & Techy:\n\n1.  **Aetheros:** (Pronounced "ee-ther-ohs") Evokes a sense of pervasive, invisible connection and control, like the ancient concept of a universal essence.\n2.  **CogniHome:** Combines "cognitive" (thinking, intelligent) with "home."\n3.  **Flux Automation:** Suggests seamless, adaptable, and ever-evolving control.\n4.  **Vervant:** (From "verve" - energy, enthusiasm) Implies a lively, responsive home.\n5.  **Nexos Living:** "Nexos" (plural of nexus) means a connection or series of connections, perfect for integrated devices.\n6.  **LumenLink:** Combines "lumen" (unit of light, suggesting illumination and clarity) with "link" (connection).\n7.  **Synapse Smart:** "Synapse" is the connection between neurons, implying intelligent communication within the home.\n8.  **Kore Living:** (Pronounced "core") Suggests being at the heart of your home\'s intelligence.\n\n## Evocative & Lifestyle:\n\n9.  **Aura Abode:** "Aura" implies an invisible, pervasive quality, creating a unique atmosphere in your home.\n10. **Sanctum Sync:** "Sanctum" for a personal, private space, and "sync" for seamless integration.\n11. **Harmonia Haus:** "Harmonia" (harmony) for a balanced, integrated living space, "Haus" (German for house) adds a touch of modern design.\n12. **Zenith Home:** "Zenith" means the peak or highest point, suggesting ultimate control and comfort.\n13. **Elysian Living:** "Elysian" refers to a state of perfect happiness, implying a blissful smart home experience.\n14. **HavenFlow:** Combines "haven" (a place of safety and peace) with "flow" (seamless operation).\n15. **Veridia Home:** (From "verdant," green, fresh) Implies a fresh, smart, and perhaps energy-efficient home.\n\n## Playful & Catchy:\n\n16. **Wink Smart:** Suggests an effortless, almost magical interaction with your home.\n17. **Kite Control:** Implies light, easy, and elevated control over your environment.\n18. **PebbleConnect:** Simple, organic, and suggests small, powerful connections.\n19. **Iris Smart:** "Iris" (the colored part of the eye, also a flower) suggests vision, perception, and beauty.\n20. **Halo Home:** Implies a protective, radiant, and encompassing smart environment.\n\n## Tips for Choosing:\n\n*   **Check Domain Availability:** Crucial for online presence.\n*   **Social Media Handles:** See if the name is available on major platforms.\n*   **Trademark Search:** A more in-depth legal check is advisable before committing.\n*   **Pronunciation & Spelling:** Is it easy to say, remember, and spell?\n*   **Target Audience:** Does the name resonate with who you\'re trying to reach?\n*   **Meaning:** Does it convey the essence of your brand?\n\nGood luck!' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b4afb-3dac-7262-bac5-65b177f9e551-0' usage_metadata={'input_tokens': 15, 'output_tokens': 2114, 'total_tokens': 2129, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1395}}
# OpenAI response: content='IntelliHome Technologies' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 4, 'prompt_tokens': 21, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CpuutJCUAmlFFX2fZ2mrrMxqJJIP7', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b4afb-6c7d-7b21-930b-a8abe63c134a-0' usage_metadata={'input_tokens': 21, 'output_tokens': 4, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# # without Prompt Template

# %%
# Direct invocation without PromptTemplate

# Gemini
response_gemini = gemini_llm.invoke("Give me a creative name for a company that makes smart home devices.")
print("Gemini direct response:", response_gemini)

# OpenAI
response_openai = openai_llm.invoke("Give me a creative name for a company that makes smart home devices.")
print("OpenAI direct response:", response_openai)
# Out:
# Gemini direct response: content='Here are some creative names for a smart home device company, categorized by their vibe:\n\n---\n\n## Modern & Tech-Focused\n\nThese names evoke innovation, intelligence, and sleek design.\n\n1.  **AuraHome:** (Implies a protective, intelligent presence in the home)\n2.  **Veridian Living:** (Veridian means a shade of green, suggesting eco-friendly tech and a vibrant, modern lifestyle)\n3.  **KinetiQ Home:** (KinetiQ suggests movement, energy, and intelligence; the \'Q\' adds a modern edge)\n4.  **NexaLiving:** (Nexa implies connection and the next generation of living)\n5.  **Synapse Systems:** (Synapses are connections in the brain, suggesting intelligent, interconnected devices)\n6.  **Luminary Logic:** (Luminary for light/enlightenment, Logic for smart processing)\n7.  **Orbital Automation:** (Suggests things working in perfect sync, like planets in orbit)\n8.  **EchoSphere Technologies:** (Evokes a comprehensive, responsive home environment)\n9.  **VerveTech:** (Verve means energy, enthusiasm, suggesting dynamic and lively smart homes)\n10. **Aethel Core:** (Aethel is Old English for noble, suggesting high quality and foundational intelligence)\n\n---\n\n## Comfort & Lifestyle Focused\n\nThese names emphasize the ease, comfort, and enhanced living experience.\n\n11. **FlowState Living:** (Suggests a harmonious, effortless, and optimized home environment)\n12. **HavenSync:** (Combines "haven" for comfort/safety with "sync" for seamless integration)\n13. **Curated Comfort:** (Highlights the personalized, tailored experience of a smart home)\n14. **SereneSpaces:** (Focuses on the peace and tranquility brought by automated living)\n15. **Hearth & Hive:** (Hearth for home warmth, Hive for interconnected activity – cozy and smart)\n16. **AbodeHarmonix:** (Abode for dwelling, Harmonix for balanced and synchronized living)\n17. **Mindful Dwell:** (Suggests a home that anticipates needs and creates a thoughtful living space)\n18. **Glowstone Home:** (Evokes warmth, subtle light, and a touch of natural intelligence)\n19. **Zenith Living:** (Zenith means the highest point, implying peak comfort and experience)\n20. **CalmQuarters:** (Directly communicates the peaceful, controlled environment)\n\n---\n\n## Evocative & Unique\n\nThese names are a bit more abstract, memorable, and leave room for brand interpretation.\n\n21. **Vivido Home:** (Sounds lively, clear, and bright – like a home brought to life)\n22. **Lyra Home:** (Lyra is a constellation, suggesting celestial harmony and advanced tech)\n23. **Confluence Connect:** (Confluence means a coming together, implying seamless integration)\n24. **TerraLux:** (Terra for earth/home, Lux for light/illumination – a grounded yet enlightened home)\n25. **Solara Smart:** (Solara evokes sun, light, warmth – a bright and efficient home)\n26. **Quanta Dwell:** (Quanta for fundamental units of energy, suggesting precision and efficiency)\n27. **Altera Living:** (Altera means "other" or "another," implying a transformed, superior way of living)\n28. **CogniNest:** (Cogni for cognition/intelligence, Nest for home – an intelligent sanctuary)\n29. **ChronoSense:** (Chrono for time, Sense for awareness – a home that understands your schedule)\n30. **Emberlink:** (Ember for warmth/hearth, Link for connectivity – a modern, warm connection)\n\n---\n\nWhen choosing, consider:\n\n*   **Availability:** Is the domain name available? Social media handles?\n*   **Memorability:** Is it easy to remember and pronounce?\n*   **Relevance:** Does it convey what your company does?\n*   **Longevity:** Will it still sound good in 5-10 years?\n*   **Target Audience:** Does it appeal to your ideal customer?\n\nGood luck!' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b4afb-74d4-7d72-a7f4-bd29d4c66c49-0' usage_metadata={'input_tokens': 15, 'output_tokens': 2199, 'to ...
# OpenAI direct response: content='IntelliHome Technologies' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 4, 'prompt_tokens': 21, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CpuvAp6hfmrBk5arww83UEKlC2TWA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b4afb-afb2-74b1-9bde-df43c01bc646-0' usage_metadata={'input_tokens': 21, 'output_tokens': 4, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate

# %%
# PromptTemplate (single string prompt)
prompt = PromptTemplate(
    input_variables=["product"],
    template="Give me a creative name for a company that makes {product}?",
)
response_openai_prompt = openai_llm.invoke(prompt.format(product="smart home devices"))
print("OpenAI PromptTemplate response:", response_openai_prompt)

# ChatPromptTemplate (structured chat prompt)
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a creative assistant."),
    ("human", "Give me a creative name for a company that makes {product}?")
])
response_openai_chat = openai_llm.invoke(
    chat_prompt.format(product="smart home devices")
)
print("OpenAI ChatPromptTemplate response:", response_openai_chat)
# Out:
# OpenAI PromptTemplate response: content='IntelliHome Technologies' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 4, 'prompt_tokens': 21, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CpuvAFhotKxaz1bL5bOADSoUCmSOj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b4afb-b3ce-7443-801c-8f5f0f7b9481-0' usage_metadata={'input_tokens': 21, 'output_tokens': 4, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# OpenAI ChatPromptTemplate response: content='Sure! How about "IntelliHome Innovations"?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 31, 'total_tokens': 42, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CpuvA7qPYq7vzqtVopDJK0ZgLeuwc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b4afb-b54b-7910-af4f-5ab89f06ae5e-0' usage_metadata={'input_tokens': 31, 'output_tokens': 11, 'total_tokens': 42, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# # from langchain_core.prompts import PromptTemplate, ChatPromptTemplate

# %%
# ...existing code...
# ChatPromptTemplate: from_messages vs from_template

# 1) from_messages – structured chat with roles
#    - You pass a list of (role, message) pairs: system / human / ai
#    - Good for multi-turn conversations and clearly separating instructions vs user input
chat_prompt_from_messages = ChatPromptTemplate.from_messages([
    ("system", "You are a creative assistant."),
    ("human", "Give me a creative name for a company that makes {product}?")
])

response_from_messages = openai_llm.invoke(
    chat_prompt_from_messages.format(product="smart home devices")
)
print("OpenAI ChatPromptTemplate.from_messages response:", response_from_messages)

# 2) from_template – single chat message template
#    - You pass one string that becomes a single chat message
#    - Simpler; prompt text and instructions are combined in one message
chat_prompt_from_template = ChatPromptTemplate.from_template(
    "You are a creative assistant. "
    "Give me a creative name for a company that makes {product}?"
)

response_from_template = openai_llm.invoke(
    chat_prompt_from_template.format(product="smart home devices")
)
print("OpenAI ChatPromptTemplate.from_template response:", response_from_template)
# ...existing code...
# Out:
# OpenAI ChatPromptTemplate.from_messages response: content='Sure! How about "IntelliHome Innovations"?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 31, 'total_tokens': 42, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-Cpv4oWpsWYkX04LZiDmfUfsekKegt', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b4b04-d498-7ca3-8fc9-aea5dca6ae0d-0' usage_metadata={'input_tokens': 31, 'output_tokens': 11, 'total_tokens': 42, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# OpenAI ChatPromptTemplate.from_template response: content='InnovateHome Technologies' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 29, 'total_tokens': 34, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-Cpv4p4gmtaoQ5sxXyIQAncPU0f19F', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b4b04-d6ce-7bf2-b06c-c3aac05b9603-0' usage_metadata={'input_tokens': 29, 'output_tokens': 5, 'total_tokens': 34, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# # time out, stop, token limit

# %%
# Initialize LLMs
gemini_llm2 = ChatGoogleGenerativeAI(
    temperature=0,
    model="gemini-2.5-flash",
    google_api_key=GEMINI_API_KEY,
    max_output_tokens=256,          # limit Gemini response length
    stop_sequences=["\nHuman:"],    # stop when these sequences appear
    timeout=30.0                    # seconds
)

openai_llm2 = ChatOpenAI(
    temperature=0,
    model="gpt-3.5-turbo",
    openai_api_key=OPENAI_API_KEY,
    max_tokens=256,                 # limit OpenAI response length
    stop=["\nHuman:"],              # stop when these sequences appear
    timeout=30.0                    # seconds
)
# Out:
# Unexpected argument 'stop_sequences' provided to ChatGoogleGenerativeAI.
# /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3699: UserWarning: WARNING! stop_sequences is not default parameter.
#                 stop_sequences was transferred to model_kwargs.
#                 Please confirm that stop_sequences is what you intended.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Test the LLMs with max_tokens / timeout settings

# Gemini (using gemini_llm2)
try:
    resp_gemini2 = gemini_llm2.invoke(
        "Give me 5 creative names for a company that makes smart home devices."
    )
    print("Gemini_llm2 response:", resp_gemini2)
except Exception as e:
    print("Gemini_llm2 error:", e)

# OpenAI (using openai_llm2)
try:
    resp_openai2 = openai_llm2.invoke(
        "Give me 5 creative names for a company that makes smart home devices."
    )
    print("OpenAI_llm2 response:", resp_openai2)
except Exception as e:
    print("OpenAI_llm2 error:", e)
# Out:
# Gemini_llm2 response: content='Here are 5 creative names for a company that makes smart home devices, each with a slightly different flavor:\n\n1.  **AuraSync:**\n    *   **Meaning:** "Aura" evokes the atmosphere or invisible presence within a home, while "Sync" refers to seamless connection and harmony between devices.\n    *   **Vibe:** Modern, integrated, sophisticated, effortless.\n\n2.  **Nexus Living:**\n    *   **Meaning:** "Nexus" means a central link or connection, implying that the devices are the core of a connected, intelligent home. "Living" keeps it grounded in the human experience.\n    *   **Vibe:** Centralized, smart hub, essential, contemporary.\n\n3.  **CoreHaven:**\n    *   **Meaning:** "Core" suggests the essential, fundamental intelligence and control, while "Haven" refers to the home as a safe, comfortable, and personalized sanctuary.\n    *   **Vibe:** Secure, comforting, foundational, personalized sanctuary.\n\n4.  **KinetiSense:**\n    *   **Meaning:** "Kinetic" refers to motion, energy, and dynamic activity, suggesting responsive and proactive smart devices. "Sense" implies awareness, intuition, and the ability to detect.\n    *   **Vibe:** Dynamic, intelligent, intuitive, futuristic, responsive.\n\n5.  **Vigilight:**\n    *   **Meaning:** A blend of "Vigil" (watchful, attentive) and "Light" (illumination, insight, ease, and smart lighting solutions). It suggests devices that are constantly aware and bring clarity and simplicity.\n    *   **Vibe:** Attentive, secure, illuminating, intelligent, simplifying.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b4b0d-f7d4-70b1-a95a-4b708e3abdbc-0' usage_metadata={'input_tokens': 16, 'output_tokens': 1720, 'total_tokens': 1736, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1361}}
# OpenAI_llm2 response: content='1. IntelliHome Innovations\n2. SmartLiving Solutions\n3. TechNest Technologies\n4. HomeIQ Systems\n5. SmartSavvy Innovations' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 22, 'total_tokens': 56, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CpvEdxK4Ms20MN0M3WuTMhVh6OQUQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b4b0e-1c98-7542-abe6-cba189081006-0' usage_metadata={'input_tokens': 22, 'output_tokens': 34, 'total_tokens': 56, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
